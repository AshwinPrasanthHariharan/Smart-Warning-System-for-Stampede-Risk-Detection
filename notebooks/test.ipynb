# %% [markdown]
# ## Import Test

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
from pathlib import Path

# Add src to path
import sys
sys.path.insert(0, '../')

from src.dataset_pipeline import DatasetLoader
print("DatasetLoader imported successfully")
# Out:
# DatasetLoader imported successfully

# %%
# Set your image and annotation directories
image_dir = "./dataset/WorldExpo'10/part_B_final/train_data/images"
gt_dir = "./dataset/WorldExpo'10/part_B_final/train_data/ground_truth/"

# Create the loader
loader = DatasetLoader(image_dir, gt_dir)

# %%
for sample in loader:
    image = sample["image"]         # numpy array (image)
    points = sample["points"]       # numpy array (points) or None
    count = sample["count"]         # int (number of points)
    path = sample["path"]           # str (image path)

    print(f"Image: {path}, Count: {count}")
