# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
from pathlib import Path

# Add src to path
import sys
sys.path.insert(0, '../')

from src.dataset_pipeline import DatasetLoader
from src.density_estimation import YoloDetector, DensityCalculator, AnnotationReader

print("Imports successful!")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 11
#       8 sys.path.insert(0, '../')
#      10 from src.dataset_pipeline import DatasetLoader
# ---> 11 from src.density_estimation import YoloDetector, DensityCalculator, AnnotationReader
#      13 print("Imports successful!")
#
# File ~/HS202_repo/notebooks/../src/density_estimation/__init__.py:1
# ----> 1 from .yolo_detector import YoloDetector
#       2 from .density_calculator import DensityCalculator
#       3 from .annotation_reader import AnnotationReader
#
# ImportError: cannot import name 'YoloDetector' from 'src.density_estimation.yolo_detector' (/home/Ashwin/HS202_repo/notebooks/../src/density_estimation/yolo_detector.py)

# %% [markdown]
# ## Load Dataset

# %%
# Load PETS dataset
loader = DatasetLoader('../configs/dataset_config.yaml')
# pets_data = loader.load_pets_dataset('../data/pets_frames/')
print("Dataset loaded")

# %% [markdown]
# ## Load Annotations

# %%
# Load annotations
# ann_reader = AnnotationReader('../data/annotations/pets_annotations.json')
# print("Annotations loaded")

# %% [markdown]
# ## Density Analysis

# %%
# Analyze crowd density patterns
# This section will contain density analysis code
